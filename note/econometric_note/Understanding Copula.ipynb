# %% [markdown]
# ### what is Copula?
#
# In short the copula is a function that takes the individual marginal distributions as arguments and yields the joint distribution function as output.

# %%
library(copula)

# %%
norm.cop <- normalCopula(0.75)
t.cop <- tCopula(0.75,df=4)
set.seed(100)
v1 <- rCopula(600,norm.cop)
v2 <- rCopula(6gh 00,t.cop)
par(mfcol=c(1,2))
plot(v1)
plot(v2)
fit.ml<-fitCopula(norm.cop,v1,method="ml")
fit.ml
# Out:
# Call: fitCopula(copula, data = data, method = "ml")
# Fit based on "maximum likelihood" and 600 2-dimensional observations.
# Copula: normalCopula
#  rho.1
# 0.7374
# The maximized loglikelihood is 241
# Optimization converged
# plot without title
